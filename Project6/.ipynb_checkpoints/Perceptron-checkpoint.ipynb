# %% [markdown]
# ### Implement Perceptron learning
#
# Assume that the linear function is w0+w1A+w2B=0 to clasify the data, find the w0,w1,w2

# %% [markdown]
# ![Picture1.png](attachment:Picture1.png)

# %%
import numpy as np
X_train=np.array([[1, 1], [3, 2], [2,4], [3, 4], [2,3]])
y_train=np.array([0,1,1,1,0])

# %%
################ finish the function below

# %%
def perceptron(x, y, lr, epochs):
    weights = [1, 1, 1]
    for itr in range(epochs):
        for index in range(len(x)):
            y_predicted = prediction(x[index], weights)
            weights[0] = weights[0] + lr * (y - y_predicted)
            weights[1] = weights[1] + lr * (y - y_predicted) * x[index][0]
            weights[2] = weights[2] + lr * (y - y_predicted) * x[index][1]
    
    return weights

# %%
def prediction(x, weights):
    y_predicted = weights[0] + (weights[1]*x[0]) + (weights[2]*x[1])
    print(y_predicted)
    return y_predicted

# %%
weight = perceptron(X_train, y_train, lr=0.1, epochs=100)
y_predicted = prediction(X_train, weights)
# Out:
# 1 1 1
# [0.7 0.8 0.8 0.8 0.7] [2.1 2.4 2.4 2.4 2.1] [1.4 1.6 1.6 1.6 1.4]
# [0.28 0.42 0.42 0.42 0.28] [-1.12 -0.68 -0.68 -0.68 -1.12] [-0.56  0.16  0.16  0.16 -0.56]
# [0.42 0.53 0.53 0.53 0.42] [-0.84 -0.36 -0.36 -0.36 -0.84] [1.68 1.92 1.92 1.92 1.68]
# [0.294 0.421 0.421 0.421 0.294] [-1.316 -0.894 -0.894 -0.894 -1.316] [-0.252  0.132  0.132  0.132 -0.252]
# [0.4214 0.5551 0.5551 0.5551 0.4214] [-0.4032 -0.1788 -0.1788 -0.1788 -0.4032] [0.2982 0.4463 0.4463 0.4463 0.2982]
# [0.38976 0.57284 0.57284 0.57284 0.38976] [-1.30452 -0.48318 -0.48318 -0.48318 -1.30452] [0.53312 0.92808 0.92808 0.92808 0.53312]
# [0.427924 0.571066 0.571066 0.571066 0.427924] [-0.640696 -0.332764 -0.332764 -0.332764 -0.640696] [1.371552 1.841968 1.841968 1.841968 1.371552]
# [0.312046 0.463039 0.463039 0.463039 0.312046] [-1.656312 -1.147308 -1.147308 -1.147308 -1.656312] [-0.482496  0.113536  0.113536  0.113536 -0.482496]
# ...

# %%
### check the accuracy on the training data
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print('Accuracy score: {}'.format(accuracy_score(y_train, y_predicted)))
